# %% [markdown]
# # Python Data Analysis Lab
# ## Task: Analyze Sales Data
#
# In this lab, you'll practice data analysis using pandas and matplotlib.

# %%
# Import required libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

print("Libraries loaded successfully!")

# %%
# Create sample data
data = {
    'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun'],
    'Sales': [15000, 18000, 22000, 25000, 28000, 30000],
    'Expenses': [12000, 14000, 16000, 18000, 20000, 22000]
}

df = pd.DataFrame(data)
df.head()

# %%
# Calculate profit
df['Profit'] = df['Sales'] - df['Expenses']
df

# %%
# Visualize the data
plt.figure(figsize=(10, 6))
plt.plot(df['Month'], df['Sales'], marker='o', label='Sales')
plt.plot(df['Month'], df['Expenses'], marker='s', label='Expenses')
plt.plot(df['Month'], df['Profit'], marker='^', label='Profit')
plt.xlabel('Month')
plt.ylabel('Amount ($)')
plt.title('Monthly Financial Analysis')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Tasks to Complete:
# 1. Calculate the average monthly profit
# 2. Find which month had the highest sales
# 3. Create a bar chart showing sales by month
# 4. Calculate the growth rate from January to June

# %%
# Your code here
# Calculate average profit
avg_profit = df['Profit'].mean()
print(f"Average Monthly Profit: ${avg_profit:,.2f}")

# Find month with highest sales
max_sales_month = df.loc[df['Sales'].idxmax(), 'Month']
print(f"Highest Sales Month: {max_sales_month}")
